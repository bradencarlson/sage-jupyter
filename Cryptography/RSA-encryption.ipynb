# %%
def PadMessage(message: str, N: int):
    PW = []
    digits = ""
    for letter in message:
        if letter== "a": digits = digits + "10"; 
        if letter== "b": digits = digits + "11"; 
        if letter== "c": digits = digits + "12";
        if letter== "d": digits = digits + "13"; 
        if letter== "e": digits = digits + "14"; 
        if letter== "f": digits = digits + "15"; 
        if letter== "g": digits = digits + "16"; 
        if letter== "h": digits = digits + "17"; 
        if letter== "i": digits = digits + "18"; 
        if letter== "j": digits = digits + "19"; 
        if letter== "k": digits = digits + "20"; 
        if letter== "l": digits = digits + "21";
        if letter== "m": digits = digits + "22"; 
        if letter== "n": digits = digits + "23"; 
        if letter== "o": digits = digits + "24"; 
        if letter== "p": digits = digits + "25"; 
        if letter== "q": digits = digits + "26"; 
        if letter== "r": digits = digits + "27"; 
        if letter== "s": digits = digits + "28"; 
        if letter== "t": digits = digits + "29"; 
        if letter== "u": digits = digits + "30"; 
        if letter== "v": digits = digits + "31"; 
        if letter== "w": digits = digits + "32"; 
        if letter== "x": digits = digits + "33"; 
        if letter== "y": digits = digits + "34"; 
        if letter== "z": digits = digits + "35"; 
        if letter== "A": digits = digits + "36"; 
        if letter== "B": digits = digits + "37"; 
        if letter== "C": digits = digits + "38"; 
        if letter== "D": digits = digits + "39"; 
        if letter== "E": digits = digits + "40"; 
        if letter== "F": digits = digits + "41"; 
        if letter== "G": digits = digits + "42"; 
        if letter== "H": digits = digits + "43"; 
        if letter== "I": digits = digits + "44"; 
        if letter== "J": digits = digits + "45"; 
        if letter== "K": digits = digits + "46"; 
        if letter== "L": digits = digits + "47"; 
        if letter== "M": digits = digits + "48"; 
        if letter== "N": digits = digits + "49"; 
        if letter== "O": digits = digits + "50"; 
        if letter== "P": digits = digits + "51";
        if letter== "Q": digits = digits + "52"; 
        if letter== "R": digits = digits + "53"; 
        if letter== "S": digits = digits + "54"; 
        if letter== "T": digits = digits + "55"; 
        if letter== "U": digits = digits + "56"; 
        if letter== "V": digits = digits + "57"; 
        if letter== "W": digits = digits + "58"; 
        if letter== "X": digits = digits + "59"; 
        if letter== "Y": digits = digits + "60"; 
        if letter== "Z": digits = digits + "61"; 
        if letter== " ": digits = digits + "62"; 
        if letter== ".": digits = digits + "63"; 
        if letter== ",": digits = digits + "64"; 
        if letter== "?": digits = digits + "65"; 
        if letter== "!": digits = digits + "66";
        if letter== "$": digits = digits + "67"; 
        if letter== "%": digits = digits + "68"; 
        if letter== "&": digits = digits + "69";
        if letter== "0": digits = digits + "70"; 
        if letter== "1": digits = digits + "71"; 
        if letter== "2": digits = digits + "72"; 
        if letter== "3": digits = digits + "73"; 
        if letter== "4": digits = digits + "74"; 
        if letter== "5": digits = digits + "75"; 
        if letter== "6": digits = digits + "76"; 
        if letter== "7": digits = digits + "77"; 
        if letter== "8": digits = digits + "78"; 
        if letter== "9": digits = digits + "79"; 
        if letter== "+": digits = digits + "80"; 
        if letter== "-": digits = digits + "81"; 
        if letter== "*": digits = digits + "82"; 
        if letter== "/": digits = digits + "83"; 
        if letter== "=": digits = digits + "84"; 
        if letter== "^": digits = digits + "85"; 
        if letter== "@": digits = digits + "86"; 
        if letter== "#": digits = digits + "87"; 
        if letter== "(": digits = digits + "88";
        if letter== ")": digits = digits + "89";
        if letter== ";": digits = digits + "90"; 
        if letter== ":": digits = digits + "91"; 
        if letter== "<": digits = digits + "92"; 
        if letter== ">": digits = digits + "93"; 
        if letter== "'": digits = digits + "94"; 
        if letter== "[": digits = digits + "95"; 
        if letter== "]": digits = digits + "96"; 
        if letter== "{": digits = digits + "97"; 
        if letter== "}": digits = digits + "98"; 
        if letter== "_": digits = digits + "99";
        
        if len(digits) > N:
            PW.append(int(digits[0:N]))
            digits = digits[N:]
    return PW

# %%
def alphabetize(digits):
    letters = ""
    for digit in digits:
        if digit== "10": letters.append("a"); 
        if digit== "11": letters.append("b"); 
        if digit== "12": letters.append("c"); 
        if digit== "13": letters.append("d");
        if digit== "14": letters.append("e"); 
        if digit== "15": letters.append("f"); 
        if digit== "16": letters.append("g"); 
        if digit== "17": letters.append("h"); 
        if digit== "18": letters.append("i");
        if digit== "19": letters.append("j");
        if digit== "20": letters.append("k"); 
        if digit== "21": letters.append("l"); 
        if digit== "22": letters.append("m");
        if digit== "23": letters.append("n"); 
        if digit== "24": letters.append("o");
        if digit== "25": letters.append("p"); 
        if digit== "26": letters.append("q"); 
        if digit== "27": letters.append("r"); 
        if digit== "28": letters.append("s");
        if digit== "29": letters.append("t"); 
        if digit== "30": letters.append("u"); 
        if digit== "31": letters.append("v"); 
        if digit== "32": letters.append("w"); 
        if digit== "33": letters.append("v"); 
        if digit== "34": letters.append("y"); 
        if digit== "35": letters.append("z"); 
        if digit== "36": letters.append("A"); 
        if digit== "37": letters.append("B"); 
        if digit== "38": letters.append("C"); 
        if digit== "39": letters.append("D"); 
        if digit== "40": letters.append("E"); 
        if digit== "41": letters.append("F"); 
        if digit== "42": letters.append("G"); 
        if digit== "43": letters.append("H"); 
        if digit== "44": letters.append("I"); 
        if digit== "45": letters.append("J"); 
        if digit== "46": letters.append("K"); 
        if digit== "47": letters.append("L"); 
        if digit== "48": letters.append("M"); 
        if digit== "49": letters.append("N"); 
        if digit== "50": letters.append("O");
        if digit== "51": letters.append("P");
        if digit== "52": letters.append("Q"); 
        if digit== "53": letters.append("R"); 
        if digit== "54": letters.append("S"); 
        if digit== "55": letters.append("T"); 
        if digit== "56": letters.append("U"); 
        if digit== "57": letters.append("V"); 
        if digit== "58": letters.append("W"); 
        if digit== "59": letters.append("X"); 
        if digit== "60": letters.append("Y"); 
        if digit== "61": letters.append("Z"); 
        if digit== "62": letters.append(" "); 
        if digit== "63": letters.append("."); 
        if digit== "64": letters.append(","); 
        if digit== "65": letters.append("?"); 
        if digit== "66": letters.append("!"); 
        if digit== "67": letters.append("$"); 
        if digit== "68": letters.append("%"); 
        if digit== "69": letters.append("&");
        if digit== "70": letters.append("0"); 
        if digit== "71": letters.append("1"); 
        if digit== "72": letters.append("2"); 
        if digit== "73": letters.append("3"); 
        if digit== "74": letters.append("4"); 
        if digit== "75": letters.append("5"); 
        if digit== "76": letters.append("6"); 
        if digit== "77": letters.append("7"); 
        if digit== "78": letters.append("8"); 
        if digit== "79": letters.append("9"); 
        if digit== "80": letters.append("+"); 
        if digit== "81": letters.append("-"); 
        if digit== "82": letters.append("*"); 
        if digit== "83": letters.append("/"); 
        if digit== "84": letters.append("="); 
        if digit== "85": letters.append("^"); 
        if digit== "86": letters.append("@"); 
        if digit== "87": letters.append("#"); 
        if digit== "88": letters.append("("); 
        if digit== "89": letters.append(")");
        if digit== "90": letters.append(";");
        if digit== "91": letters.append(":"); 
        if digit== "92": letters.append("<"); 
        if digit== "93": letters.append(">"); 
        if digit== "94": letters.append("'"); 
        if digit== "95": letters.append("["); 
        if digit== "96": letters.append("]"); 
        if digit== "97": letters.append("{"); 
        if digit== "98": letters.append("}"); 
        if digit== "99": letters.append("_");
    return letters

# %%
print(PadMessage("Hello this is some sort of message", 10))
print(digitize("Hello this is some sort of message"))
# Out:
# [4314212124, 6229171828, 6218286228, 2422146228, 2427296224, 1562221428]
# 43142121246229171828621828622824221462282427296224156222142828101614
